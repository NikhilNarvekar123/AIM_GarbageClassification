# %%
#Jayita Malik 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pathlib
import random
import glob

#CURRENT EPOCHS = 50
#CURRENT BATCH = 32


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2 #Regulizer for overfitting
import PIL

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
images_path = os.path.join(os.path.realpath('..'), "input", "garbage-classification", "Garbage classification", "Garbage classification")
images_path = pathlib.Path(images_path)

total = len(list(images_path.glob('*/*.jpg')))

print(f"total images: {total}")

batch_size = 32
print(f"batch size: {batch_size}")
img_height = 180
img_width = 180
rescale = Rescaling(scale=1.0/255)
# Out:
# total images: 2527
# batch size: 32

# %%
train_ds = image_dataset_from_directory(
  images_path,
  validation_split=0.3,
  subset="training",
  seed=1232376,
  image_size=(img_height, img_width),
  batch_size=batch_size)

train_ds = train_ds.map(lambda image,label:(rescale(image),label))
# Out:
# Found 2527 files belonging to 6 classes.
# Using 1769 files for training.

# %%
val_ds = image_dataset_from_directory(
  images_path,
  validation_split=0.3,
  subset="validation",
  seed=1232376,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = val_ds.map(lambda image,label:(rescale(image),label))
# Out:
# Found 2527 files belonging to 6 classes.
# Using 758 files for validation.

# %%
num_classes = 6

#layers = 3
model = tf.keras.Sequential([
  #layers.Conv2D(16, 5, activation='relu'),
  #layers.MaxPooling2D(pool_size=(2, 2)),
  #layers.Dropout(0.20),  
  
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.20),    
    
  layers.Conv2D(32, 5, activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.20),   
    
  layers.Conv2D(32, 7, activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.20),   
    
  layers.Conv2D(64, 7, activation='relu'),
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.20),  

  layers.Conv2D(128, 5, activation='relu'),#Filter, kernel size 
  layers.MaxPooling2D(pool_size=(2, 2)),
  layers.Dropout(0.20),  
    
  #layers.kernel_regularizer=l2(0.0005),  
    
  layers.Flatten(),
  layers.Dense(64, activation='relu'),
  #layers.Dense(128, activation='relu'),
  #layers.Dense(128, activation='relu')  
  layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  batch_size=batch_size,  
  epochs=50,
  shuffle=True  #Turning the shuffle on 
)

model.summary()
# Out:
# Epoch 1/50
# 56/56 [==============================] - 8s 114ms/step - loss: 1.7565 - accuracy: 0.2059 - val_loss: 1.6889 - val_accuracy: 0.2375
# Epoch 2/50
# 56/56 [==============================] - 6s 108ms/step - loss: 1.6129 - accuracy: 0.3102 - val_loss: 1.6125 - val_accuracy: 0.3430
# Epoch 3/50
# 56/56 [==============================] - 7s 114ms/step - loss: 1.5484 - accuracy: 0.3223 - val_loss: 1.4696 - val_accuracy: 0.3760
# Epoch 4/50
# 56/56 [==============================] - 7s 108ms/step - loss: 1.5389 - accuracy: 0.3521 - val_loss: 1.4289 - val_accuracy: 0.4261
# Epoch 5/50
# 56/56 [==============================] - 7s 107ms/step - loss: 1.5009 - accuracy: 0.3742 - val_loss: 1.4376 - val_accuracy: 0.4420
# Epoch 6/50
# 56/56 [==============================] - 7s 110ms/step - loss: 1.4834 - accuracy: 0.3815 - val_loss: 1.4337 - val_accuracy: 0.4142
# Epoch 7/50
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3865 - accuracy: 0.4389 - val_loss: 1.3478 - val_accuracy: 0.4103
# Epoch 8/50
# 56/56 [==============================] - 7s 121ms/step - loss: 1.3412 - accuracy: 0.4414 - val_loss: 1.3392 - val_accuracy: 0.4565
# Epoch 9/50
# 56/56 [==============================] - 7s 113ms/step - loss: 1.2697 - accuracy: 0.4958 - val_loss: 1.1677 - val_accuracy: 0.5844
# Epoch 10/50
# 56/56 [==============================] - 6s 106ms/step - loss: 1.1849 - accuracy: 0.5543 - val_loss: 1.1642 - val_accuracy: 0.5976
# Epoch 11/50
# 56/56 [==============================] - 7s 112ms/step - loss: 1.1465 - accuracy: 0.5746 - val_loss: 1.2252 - val_accuracy: 0.5356
# Epoch 12/50
# 56/56 [==============================] - 6s 106ms/step - loss: 1.1171 - accuracy: 0.5866 - val_loss: 1.1951 - val_accuracy: 0.5686
# Epoch 13/50
# 56/56 [==============================] - 7s 116ms/step - loss: 1.0768 - accuracy: 0.5939 - val_loss: 1.1137 - val_accuracy: 0.5976
# Epoch 14/50
# 56/56 [==============================] - 7s 108ms/step - loss: 1.1416 - accuracy: 0.5421 - val_loss: 1.0940 - val_accuracy: 0.6148
# Epoch 15/50
# 56/56 [==============================] - 6s 108ms/step - loss: 0.9330 - accuracy: 0.6609 - val_loss: 1.1309 - val_accuracy: 0.5858
# Epoch 16/50
# 56/56 [==============================] - 7s 110ms/step - loss: 0.9165 - accuracy: 0.6492 - val_loss: 1.1112 - val_accuracy: 0.6227
# Epoch 17/50
# 56/56 [==============================] - 6s 108ms/step - loss: 0.9173 - accuracy: 0.6407 - val_loss: 1.1063 - val_accuracy: 0.6161
# Epoch 18/50
# 56/56 [==============================] - 7s 118ms/step - loss: 0.8275 - accuracy: 0.6857 - val_loss: 1.0545 - val_accuracy: 0.6372
# Epoch 19/50
# 56/56 [==============================] - 7s 110ms/step - loss: 0.8293 - accuracy: 0.6874 - val_loss: 1.2797 - val_accuracy: 0.5501
# Epoch 20/50
# 56/56 [==============================] - 6s 107ms/step - loss: 0.8230 - accuracy: 0.7000 - val_loss: 1.1331 - val_accuracy: 0.5989
# Epoch 21/50
# 56/56 [==============================] - 7s 109ms/step - loss: 0.7123 - accuracy: 0.7328 - val_loss: 1.1392 - val_accuracy: 0.6266
# Epoch 22/50
# 56/56 [==============================] - 6s 106ms/step - loss: 0.6610 - accuracy: 0.7613 - val_loss: 1.1595 - val_accuracy: 0.6372
# Epoch 23/50
# 56/56 [==============================] - 7s 115ms/step - loss: 0.6353 - accuracy: 0.7671 - val_loss: 1.2905 - val_accuracy: 0.5923
# Epoch 24/50
# 56/56 [==============================] - 7s 111ms/step - loss: 0.6803 - accuracy: 0.7438 - val_loss: 1.2085 - val_accuracy: 0.6451
# Epoch 25/50
# 56/56 [==============================] - 7s 108ms/step - loss: 0.5517 - accuracy: 0.7968 - val_loss: 1.4215 - val_accuracy: 0.5923
# Epoch 26/50
# 56/56 [==============================] - 7s 112ms/step - loss: 0.6805 - accuracy: 0.7456 - val_loss: 1.2110 - val_accuracy: 0.6161
# Epoch 27/50
# 56/56 [==============================] - 7s 112ms/step - loss: 0.4958 - accuracy: 0.8207 - val_loss: 1.2075 - val_accuracy: 0.6398
# Epoch 28/50
# 56/56 [==============================] - 7s 106ms/step - loss: 0.4743 - accuracy: 0.8340 - val_loss: 1.3694 - val_accuracy: 0.6187
# Epoch 29/50
# 56/56 [==============================] - 7s 112ms/step - loss: 0.4434 - accuracy: 0.8364 - val_loss: 1.2498 - val_accuracy: 0.6491
# Epoch 30/50
# 56/56 [==============================] - 7s 108ms/step - loss: 0.3984 - accuracy: 0.8486 - val_loss: 1.2780 - val_accuracy: 0.6187
# Epoch 31/50
# 56/56 [==============================] - 7s 109ms/step - loss: 0.5757 - accuracy: 0.7925 - val_loss: 1.4876 - val_accuracy: 0.6187
# Epoch 32/50
# 56/56 [==============================] - 7s 111ms/step - loss: 0.4578 - accuracy: 0.8325 - val_loss: 1.3703 - val_accuracy: 0.6372
# Epoch 33/50
# 56/56 [==============================] - 7s 106ms/step - loss: 0.4040 - accuracy: 0.8572 - val_loss: 1.3922 - val_accuracy: 0.6385
# Epoch 34/50
# 56/56 [==============================] - 7s 111ms/step - loss: 0.4187 - accuracy: 0.8509 - val_loss: 1.3664 - val_accuracy: 0.6398
# Epoch 35/50
# 56/56 [==============================] - 7s 110ms/step - loss: 0.3054 - accuracy: 0.8922 - val_loss: 1.5939 - val_accuracy: 0.6412
# Epoch 36/50
# 56/56 [==============================] - 7s 110ms/step - loss: 0.3497 - accuracy: 0.8616 - val_loss: 1.5065 - val_accuracy: 0.6293
# Epoch 37/50
# 56/56 [==============================] - 7s 116ms/step - loss: 0.3915 - accuracy: 0.8614 - val_loss: 1.5316 - val_accuracy: 0.5976
# Epoch 38/50
# 56/56 [==============================] - 7s 111ms/step - loss: 0.3730 - accuracy: 0.8661 - val_loss: 1.5332 - val_accuracy: 0.6319
# Epoch 39/50
# 56/56 [==============================] - 7s 109ms/step - loss: 0.3137 - accuracy: 0.8831 - val_loss: 1.5666 - val_accuracy: 0.6174
# Epoch 40/50
# 56/56 [==============================] - 6s 107ms/step - loss: 0.2850 - accuracy: 0.8957 - val_loss: 1.6789 - val_accuracy: 0.6240
# Epoch 41/50
# 56/56 [==============================] - 7s 110ms/step - loss: 0.2888 - accuracy: 0.8958 - val_loss: 1.5361 - val_accuracy: 0.6319
# Epoch 42/50
# 56/56 [==============================] - 7s 118ms/step - loss: 0.2718 - accuracy: 0.9028 - val_loss: 1.5345 - val_accuracy: 0.6293
# Epoch 43/50
# 56/56 [==============================] - 6s 105ms/step - loss: 0.2100 - accuracy: 0.9192 - val_loss: 1.7397 - val_accuracy: 0.6266
# Epoch 44/50
# 56/56 [==============================] - 7s 113ms/step - loss: 0.2605 - accuracy: 0.9100 - val_loss: 1.6364 - val_accuracy: 0.6214
# Epoch 45/50
# 56/56 [==============================] - 6s 107ms/step - loss: 0.3517 - accuracy: 0.8783 - val_loss: 1.8737 - val_accuracy: 0.5818
# Epoch 46/50
# 56/56 [==============================] - 7s 108ms/step - loss: 0.3121 - accuracy: 0.8790 - val_loss: 1.6102 - val_accuracy: 0.6253
# Epoch 47/50
# 56/56 [==============================] - 7s 118ms/step - loss: 0.3189 - accuracy: 0.8858 - val_loss: 1.7605 - val_accuracy: 0.5923
# Epoch 48/50
# 56/56 [==============================] - 6s 106ms/step - loss: 0.3324 - accuracy: 0.8866 - val_loss: 1.7249 - val_accuracy: 0.6266
# Epoch 49/50
# 56/56 [==============================] - 7s 111ms/step - loss: 0.2058 - accuracy: 0.9350 - val_loss: 1.5735 - val_accuracy: 0.6240
# Epoch 50/50
# 56/56 [==============================] - 6s 107ms/step - loss: 0.1859 - accuracy: 0.9285 - val_loss: 1.7863 - val_accuracy: 0.6227
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_113 (Conv2D)          (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d_113 (MaxPoolin (None, 89, 89, 32)        0
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 85, 85, 32)        25632
# _________________________________________________________________
# max_pooling2d_114 (MaxPoolin (None, 42, 42, 32)        0
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 42, 42, 32)        0
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 36, 36, 32)        50208
# _________________________________________________________________
# max_pooling2d_115 (MaxPoolin (None, 18, 18, 32)        0
# _________________________________________________________________
# dropout_115 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 12, 12, 64)        100416
# _________________________________________________________________
# max_pooling2d_116 (MaxPoolin (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 2, 2, 128)         204928
# _________________________________________________________________
# max_pooling2d_117 (MaxPoolin (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_117 (Dropout)        (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_46 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 390,726
# Trainable params: 390,726
# Non-trainable params: 0
# _________________________________________________________________
